# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\Muthu B\Downloads\Election_Data.xlsx", sheet_name = 'Election_Dataset_Two Classes')

# %%
data
# Out:
#       Unnamed: 0          vote  age  economic.cond.national  \
# 0              1        Labour   43                       3
# 1              2        Labour   36                       4
# 2              3        Labour   35                       4
# 3              4        Labour   24                       4
# 4              5        Labour   41                       2
# ...          ...           ...  ...                     ...
# 1520        1521  Conservative   67                       5
# 1521        1522  Conservative   73                       2
# 1522        1523        Labour   37                       3
# 1523        1524  Conservative   61                       3
# 1524        1525  Conservative   74                       2
#
#       economic.cond.household  Blair  Hague  Europe  political.knowledge  \
# 0                           3      4      1       2                    2
# 1                           4      4      4       5                    2
# ...

# %%
data.shape
# Out:
# (1525, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1525 non-null   int64
#  1   vote                     1525 non-null   object
#  2   age                      1525 non-null   int64
#  3   economic.cond.national   1525 non-null   int64
#  4   economic.cond.household  1525 non-null   int64
#  5   Blair                    1525 non-null   int64
#  6   Hague                    1525 non-null   int64
#  7   Europe                   1525 non-null   int64
#  8   political.knowledge      1525 non-null   int64
#  9   gender                   1525 non-null   object
# dtypes: int64(8), object(2)
# memory usage: 119.3+ KB

# %%
data.describe()
# Out:
#         Unnamed: 0          age  economic.cond.national  \
# count  1525.000000  1525.000000             1525.000000
# mean    763.000000    54.182295                3.245902
# std     440.373894    15.711209                0.880969
# min       1.000000    24.000000                1.000000
# 25%     382.000000    41.000000                3.000000
# 50%     763.000000    53.000000                3.000000
# 75%    1144.000000    67.000000                4.000000
# max    1525.000000    93.000000                5.000000
#
#        economic.cond.household        Blair        Hague       Europe  \
# count              1525.000000  1525.000000  1525.000000  1525.000000
# mean                  3.140328     3.334426     2.746885     6.728525
# std                   0.929951     1.174824     1.230703     3.297538
# min                   1.000000     1.000000     1.000000     1.000000
# 25%                   3.000000     2.000000     2.000000     4.000000
# ...

# %%
data.quantile(0.75) - data.quantile(0.25)
# Out:
# Unnamed: 0                 762.0
# age                         26.0
# economic.cond.national       1.0
# economic.cond.household      1.0
# Blair                        2.0
# Hague                        2.0
# Europe                       6.0
# political.knowledge          2.0
# dtype: float64

# %%
# the above output represents the IQR values for all the attributed.

# %%
print(data.var())
# Out:
# Unnamed: 0                 193929.166667
# age                           246.842075
# economic.cond.national          0.776107
# economic.cond.household         0.864810
# Blair                           1.380212
# Hague                           1.514631
# Europe                         10.873759
# political.knowledge             1.173571
# dtype: float64

# %%
print(data.std())
# Out:
# Unnamed: 0                 440.373894
# age                         15.711209
# economic.cond.national       0.880969
# economic.cond.household      0.929951
# Blair                        1.174824
# Hague                        1.230703
# Europe                       3.297538
# political.knowledge          1.083315
# dtype: float64

# %%
data.cov()
# Out:
#                             Unnamed: 0         age  economic.cond.national  \
# Unnamed: 0               193929.166667   35.476378               27.887139
# age                          35.476378  246.842075                0.256981
# economic.cond.national       27.887139    0.256981                0.776107
# economic.cond.household      14.704724   -0.607619                0.283712
# Blair                         0.828740    0.557762                0.338314
# Hague                         0.152887    0.669531               -0.216589
# Europe                       55.498688    3.568550               -0.608397
# political.knowledge           1.185696   -0.825301               -0.022546
#
#                          economic.cond.household     Blair     Hague  \
# Unnamed: 0                             14.704724  0.828740  0.152887
# age                                    -0.607619  0.557762  0.669531
# economic.cond.national                  0.283712  0.338314 -0.216589
# ...

# %%
data.corr()
# Out:
#                          Unnamed: 0       age  economic.cond.national  \
# Unnamed: 0                 1.000000  0.005128                0.071882
# age                        0.005128  1.000000                0.018567
# economic.cond.national     0.071882  0.018567                1.000000
# economic.cond.household    0.035907 -0.041587                0.346303
# Blair                      0.001602  0.030218                0.326878
# Hague                      0.000282  0.034626               -0.199766
# Europe                     0.038218  0.068880               -0.209429
# political.knowledge        0.002485 -0.048490               -0.023624
#
#                          economic.cond.household     Blair     Hague  \
# Unnamed: 0                              0.035907  0.001602  0.000282
# age                                    -0.041587  0.030218  0.034626
# economic.cond.national                  0.346303  0.326878 -0.199766
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.pairplot(data, kind="reg")  # plots scatter plots for every pair of attributes and histograms along the diagonal
plt.show()

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
fig,ax = plt.subplots(figsize=(10, 10))   
sns.heatmap(data.corr(), ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma") # the color intensity is based on 
plt.show()

# %%
data.skew()
# Out:
# age                        0.144621
# economic.cond.national    -0.240453
# economic.cond.household   -0.149552
# Blair                     -0.535419
# Hague                      0.152100
# Europe                    -0.135947
# political.knowledge       -0.426838
# dtype: float64

# %%
dups = data.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
data[dups]
# Out:
# Number of duplicate rows = 8
#               vote  age  economic.cond.national  economic.cond.household  \
# 67          Labour   35                       4                        4
# 626         Labour   39                       3                        4
# 870         Labour   38                       2                        4
# 983   Conservative   74                       4                        3
# 1154  Conservative   53                       3                        4
# 1236        Labour   36                       3                        3
# 1244        Labour   29                       4                        4
# 1438        Labour   40                       4                        3
#
#       Blair  Hague  Europe  political.knowledge  gender
# 67        5      2       3                    2    male
# 626       4      2       5                    2    male
# 870       2      2       4                    3    male
# ...

# %%
data.isnull().sum()
# Out:
# vote                       0
# age                        0
# economic.cond.national     0
# economic.cond.household    0
# Blair                      0
# Hague                      0
# Europe                     0
# political.knowledge        0
# gender                     0
# dtype: int64

# %%
data.plot(kind='box', figsize = (30,30), fontsize=20, patch_artist=True)

# %%
sns.boxplot('economic.cond.national', data = data)

# %%
sns.boxplot('economic.cond.household', data = data)

# %%
for feature in data.columns: 
    if data[feature].dtype == 'object': 
        data[feature] = pd.Categorical(data[feature]).codes

# %%
sns.distplot(data)

# %%
sns.distplot(data, hist=False)

# %%
sns.violinplot(data)

# %%
sns.distplot(data, hist_kws=dict(cumulative=True), kde_kws=dict(cumulative=True))

# %%
sns.pairplot(data)

# %%
fig,ax = plt.subplots(figsize=(10, 10))   
sns.heatmap(data.corr(), ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma") # the color intensity is based on 
plt.show()

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (1517, 9)

# %%
from sklearn.preprocessing import StandardScaler

std_scale = StandardScaler()

std_scale
# Out:
# StandardScaler()

# %%
data['vote_Stdscale'] = std_scale.fit_transform(data[['vote']])

# %%
data['age_Stdscale'] = std_scale.fit_transform(data[['age']])

# %%
data['economic.cond.national_Stdscale'] = std_scale.fit_transform(data[['economic.cond.national']])

# %%
data['economic.cond.household_Stdscale'] = std_scale.fit_transform(data[['economic.cond.household']])

# %%
data['Blair_Stdscale'] = std_scale.fit_transform(data[['Blair']])

# %%
data['Hague_Stdscale'] = std_scale.fit_transform(data[['Hague']])

# %%
data['Europe_Stdscale'] = std_scale.fit_transform(data[['Europe']])

# %%
data['political.knowledge_Stdscale'] = std_scale.fit_transform(data[['political.knowledge']])

# %%
data['gender_Stdscale'] = std_scale.fit_transform(data[['gender']])

# %%
data = data.drop(['vote','age','economic.cond.national','economic.cond.household','Blair','Hague','Europe','political.knowledge','gender'], axis =1)

# %%
for feature in data.columns: 
    if data[feature].dtype == 'float64': 
        data[feature] = pd.Categorical(data[feature]).codes

# %%
X = data.drop('vote_Stdscale', axis=1)

# Copy target into the y dataframe. 
y = data[['vote_Stdscale']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
model_score = model.score(X_test, y_test)
print(model_score)
print(metrics.confusion_matrix(y_test, y_predict))
print(metrics.classification_report(y_test, y_predict))
# Out:
# C:\Users\Muthu B\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 0.8355263157894737
# [[113  40]
#  [ 35 268]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75       153
#            1       0.87      0.88      0.88       303
#
#     accuracy                           0.84       456
#    macro avg       0.82      0.81      0.81       456
# weighted avg       0.83      0.84      0.83       456
# C:\Users\Muthu B\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
# AUC and ROC for the training data

# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.863

# %%
# AUC and ROC for the test data


# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.865

# %%
#LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
clf = LinearDiscriminantAnalysis()
model=clf.fit(X,y)
model
# Out:
# C:\Users\Muthu B\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LinearDiscriminantAnalysis()

# %%
pred_class = model.predict(X)
data['Prediction'] = pred_class

# %%
print(metrics.confusion_matrix(y, pred_class))
# Out:
# [[314 146]
#  [105 952]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y, pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.68      0.71       460
#            1       0.87      0.90      0.88      1057
#
#     accuracy                           0.83      1517
#    macro avg       0.81      0.79      0.80      1517
# weighted avg       0.83      0.83      0.83      1517

# %%
model_score = model.score(X_test, y_test)
print(model_score)
# Out:
# 0.8399122807017544

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
NNH = KNeighborsClassifier(n_neighbors= 5 , weights = 'distance' )

# %%
NNH.fit(X_train, y_train)
# Out:
# <ipython-input-268-a58e491caeeb>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   NNH.fit(X_train, y_train)
# KNeighborsClassifier(weights='distance')

# %%
predicted_labels = NNH.predict(X_test)
NNH.score(X_test, y_test)
# Out:
# 0.8157894736842105

# %%
from sklearn.naive_bayes import GaussianNB

# %%
diab_model = GaussianNB()

diab_model.fit(X_train, y_train)
# Out:
# C:\Users\Muthu B\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# GaussianNB()

# %%
diab_train_predict = diab_model.predict(X_train)

from sklearn import metrics

print("Model Accuracy: {0:.4f}".format(metrics.accuracy_score(y_train, diab_train_predict)))
print()
# Out:
# Model Accuracy: 0.8351

# %%
diab_test_predict = diab_model.predict(X_test)

from sklearn import metrics

print("Model Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, diab_test_predict)))
print()
# Out:
# Model Accuracy: 0.8224

# %%
print("Classification Report")
print(metrics.classification_report(y_test, diab_test_predict, labels=[1, 0]))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.87      0.87      0.87       303
#            0       0.74      0.73      0.73       153
#
#     accuracy                           0.82       456
#    macro avg       0.80      0.80      0.80       456
# weighted avg       0.82      0.82      0.82       456

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'max_depth': [7, 10],
    'max_features': [4, 6],
    'min_samples_leaf': [50, 100],
    'min_samples_split': [150, 300],
    'n_estimators': [301, 501]}

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfcl = RandomForestClassifier()

grid_search = GridSearchCV(estimator = rfcl, param_grid = param_grid, cv = 3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\Muthu B\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Muthu B\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Muthu B\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
grid_search.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 6,
#  'min_samples_leaf': 50,
#  'min_samples_split': 150,
#  'n_estimators': 301}

# %%
best_grid = grid_search.best_estimator_

# %%
ytrain_predict = best_grid.predict(X_train)
ytest_predict = best_grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
confusion_matrix(y_train,ytrain_predict)
# Out:
# array([[171, 136],
#        [ 51, 703]], dtype=int64)

# %%
confusion_matrix(y_test,ytest_predict)
# Out:
# array([[ 86,  67],
#        [ 21, 282]], dtype=int64)

# %%
print(classification_report(y_train,ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.56      0.65       307
#            1       0.84      0.93      0.88       754
#
#     accuracy                           0.82      1061
#    macro avg       0.80      0.74      0.76      1061
# weighted avg       0.82      0.82      0.81      1061

# %%
print(classification_report(y_test,ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.56      0.66       153
#            1       0.81      0.93      0.87       303
#
#     accuracy                           0.81       456
#    macro avg       0.81      0.75      0.76       456
# weighted avg       0.81      0.81      0.80       456

# %%
# AUC and ROC for the training data

# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.882

# %%
# AUC and ROC for the test data


# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.874

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dTree = DecisionTreeClassifier(criterion = 'gini', random_state=1)
dTree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
print(dTree.score(X_train, y_train))
print(dTree.score(X_test, y_test))
# Out:
# 1.0
# 0.7960526315789473

# %%
dTreeR = DecisionTreeClassifier(criterion = 'gini', max_depth = 3, random_state=1)
dTreeR.fit(X_train, y_train)
print(dTreeR.score(X_train, y_train))
print(dTreeR.score(X_test, y_test))
# Out:
# 0.8086710650329878
# 0.7894736842105263

# %%
print (pd.DataFrame(dTreeR.feature_importances_, columns = ["Imp"], index = X_train.columns))
# Out:
#                                        Imp
# age_Stdscale                      0.000000
# economic.cond.national_Stdscale   0.000000
# economic.cond.household_Stdscale  0.016012
# Blair_Stdscale                    0.291569
# Hague_Stdscale                    0.514417
# Europe_Stdscale                   0.139003
# political.knowledge_Stdscale      0.038999
# gender_Stdscale                   0.000000

# %%
print(dTreeR.score(X_test , y_test))
y_predict = dTreeR.predict(X_test)

cm=metrics.confusion_matrix(y_test, y_predict, labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 0.7894736842105263

# %%
from sklearn.ensemble import BaggingClassifier

bgcl = BaggingClassifier(base_estimator=dTree, n_estimators=50,random_state=1)
#bgcl = BaggingClassifier(n_estimators=50,random_state=1)

bgcl = bgcl.fit(X_train, y_train)
# Out:
# C:\Users\Muthu B\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
y_predict = bgcl.predict(X_test)

print(bgcl.score(X_test , y_test))

cm=metrics.confusion_matrix(y_test, y_predict,labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 0.8245614035087719

# %%
from sklearn.ensemble import AdaBoostClassifier
abcl = AdaBoostClassifier(n_estimators=10, random_state=1)
abcl = abcl.fit(X_train, y_train)
# Out:
# C:\Users\Muthu B\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
y_predict = abcl.predict(X_test)
print(abcl.score(X_test , y_test))

cm=metrics.confusion_matrix(y_test, y_predict,labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 0.8201754385964912

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(n_estimators = 50,random_state=1)
gbcl = gbcl.fit(X_train, y_train)
# Out:
# C:\Users\Muthu B\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
y_predict = gbcl.predict(X_test)
print(gbcl.score(X_test, y_test))
cm=metrics.confusion_matrix(y_test, y_predict,labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 0.8289473684210527

# %%
from sklearn.ensemble import RandomForestClassifier
rfcl = RandomForestClassifier(n_estimators = 50, random_state=1)
rfcl = rfcl.fit(X_train, y_train)
# Out:
# <ipython-input-301-55b2fc342f1d>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfcl = rfcl.fit(X_train, y_train)

# %%
y_predict = rfcl.predict(X_test)
print(rfcl.score(X_test, y_test))
cm=metrics.confusion_matrix(y_test, y_predict,labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 0.8245614035087719
